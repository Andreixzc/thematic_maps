# %%
import ee
import geemap
import joblib
import numpy as np
import os
import threading
from threading import Lock
import rasterio
from rasterio.merge import merge
from rasterio.transform import from_origin
from IPython.display import display

try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ee.Initialize()

# Load RandomForest model
model = joblib.load('models/cacu/clorofila/model.joblib')
scaler = joblib.load('models/cacu/clorofila/scaler.joblib')

# Print model feature importances for debugging
print("\nModel feature importances:")
feature_names = ['B2', 'B3', 'B4', 'B5', 'B8', 'B11', 'NDCI', 'NDVI', 'FAI', 
                'B3_B2_ratio', 'B4_B3_ratio', 'B5_B4_ratio', 'Month', 'Season']
for name, importance in zip(feature_names, model.feature_importances_):
    print(f"{name}: {importance}")

# Define area of interest
aoi = ee.Geometry.Polygon([[[-45.559114, -18.954365], [-45.559114, -18.212409], 
                           [-44.839706, -18.212409], [-44.839706, -18.954365], 
                           [-45.559114, -18.954365]]])

def process_tile(tile_geometry, date_range, model, scaler):
    """Process a single tile of the area of interest"""
    # Sentinel-2 collection for tile
    sentinel2 = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
        .filterBounds(tile_geometry) \
        .filterDate(date_range[0], date_range[1]) \
        .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))
    
    # Get median image
    image = sentinel2.median().clip(tile_geometry)
    
    # Select bands of interest
    bands = ['B2', 'B3', 'B4', 'B5', 'B8', 'B11']
    original_bands = image.select(bands)
    
    # Apply water mask
    MNDWI = image.normalizedDifference(['B3', 'B11']).rename('MNDWI')
    water_mask = MNDWI.gt(0.3)
    image = image.updateMask(water_mask)
    
    # Calculate indices
    NDCI = image.normalizedDifference(['B5', 'B4']).rename('NDCI')
    NDVI = image.normalizedDifference(['B8', 'B4']).rename('NDVI')
    FAI = image.expression(
        'NIR - (RED + (SWIR - RED) * (NIR_wl - RED_wl) / (SWIR_wl - RED_wl))',
        {
            'NIR': image.select('B8'),
            'RED': image.select('B4'),
            'SWIR': image.select('B11'),
            'NIR_wl': 842,
            'RED_wl': 665,
            'SWIR_wl': 1610
        }
    ).rename('FAI')
    
    # Calculate band ratios
    B3_B2_ratio = image.select('B3').divide(image.select('B2')).rename('B3_B2_ratio')
    B4_B3_ratio = image.select('B4').divide(image.select('B3')).rename('B4_B3_ratio')
    B5_B4_ratio = image.select('B5').divide(image.select('B4')).rename('B5_B4_ratio')
    
    # Get date information
    middle_date = ee.Date(sentinel2.limit(1).first().get('system:time_start'))
    month = ee.Image.constant(middle_date.get('month')).rename('Month')
    season = ee.Image.constant(middle_date.get('month').add(2).divide(3).floor().add(1)).rename('Season')
    
    # Combine all features
    image_with_indices = image.addBands([NDCI, NDVI, FAI, B3_B2_ratio, B4_B3_ratio, 
                                       B5_B4_ratio, month, season])
    
    # Create scaled bands
    scaled_bands = []
    for i, name in enumerate(feature_names):
        scaled_band = image_with_indices.select(name) \
            .subtract(ee.Number(scaler.mean_[i])) \
            .divide(ee.Number(scaler.scale_[i])) \
            .rename(f'scaled_{name}')
        scaled_bands.append(scaled_band)
    
    # Combine scaled bands
    scaled_image = ee.Image.cat(scaled_bands)
    
    # Create prediction
    weighted_bands = []
    for i, (name, importance) in enumerate(zip(feature_names, model.feature_importances_)):
        weighted_band = scaled_image.select(f'scaled_{name}').multiply(ee.Number(importance))
        weighted_bands.append(weighted_band)
    
    predicted_image = ee.Image.cat(weighted_bands).reduce(ee.Reducer.sum()).rename('chlorophyll_pred')
    
    # Combine original bands with prediction and indices
    final_image = ee.Image.cat([
        original_bands,                    # Original spectral bands
        NDCI, NDVI, FAI,                  # Spectral indices
        predicted_image                    # Chlorophyll prediction
    ]).updateMask(water_mask)
    
    return final_image

def merge_tiff_files(directory, pattern, output_file):
    """Merge multiple TIFF files into a single file"""
    tiff_files = [os.path.join(directory, f) for f in os.listdir(directory) 
                  if f.startswith(pattern) and f.endswith('.tif')]
    
    if not tiff_files:
        raise ValueError("No TIFF files found to merge")
    
    src_files_to_mosaic = []
    try:
        for tiff in tiff_files:
            src = rasterio.open(tiff)
            src_files_to_mosaic.append(src)
        
        mosaic, out_trans = merge(src_files_to_mosaic)
        
        out_meta = src_files_to_mosaic[0].meta.copy()
        out_meta.update({
            "height": mosaic.shape[1],
            "width": mosaic.shape[2],
            "transform": out_trans,
            "count": mosaic.shape[0]  # Update band count
        })
        
        with rasterio.open(output_file, "w", **out_meta) as dest:
            dest.write(mosaic)
        
        return tiff_files
    finally:
        for src in src_files_to_mosaic:
            src.close()

def process_aoi_in_tiles(aoi, n_tiles, date_range, model, scaler, save_directory):
    """Process the area of interest in tiles with parallel processing"""
    os.makedirs(save_directory, exist_ok=True)
    
    # Get AOI bounds
    aoi_bounds = aoi.bounds().coordinates().getInfo()[0]
    xmin, ymin = aoi_bounds[0][0], aoi_bounds[0][1]
    xmax, ymax = aoi_bounds[2][0], aoi_bounds[2][1]
    
    # Calculate tile sizes
    x_step = (xmax - xmin) / n_tiles
    y_step = (ymax - ymin) / n_tiles
    
    lock = Lock()
    tile_results = []
    processed_files = []
    
    def process_and_save_tile(i, j):
        # Create tile geometry
        x0 = xmin + i * x_step
        x1 = xmin + (i + 1) * x_step
        y0 = ymin + j * y_step
        y1 = ymin + (j + 1) * y_step
        tile_geometry = ee.Geometry.Polygon([[[x0, y0], [x1, y0], [x1, y1], [x0, y1], [x0, y0]]])
        
        try:
            # Process tile
            tile_result = process_tile(tile_geometry, date_range, model, scaler)
            
            # Save tile result
            out_file = os.path.join(save_directory, f'PredictedChlorophyll_Tile_{i+1}_{j+1}.tif')
            with lock:
                geemap.ee_export_image(
                    tile_result,
                    filename=out_file,
                    scale=30,
                    region=tile_geometry
                )
                print(f'Tile {i+1}_{j+1} processed and saved: {out_file}')
                tile_results.append(tile_result)
                processed_files.append(out_file)
        except Exception as e:
            print(f"Error processing tile {i+1}_{j+1}: {str(e)}")
    
    # Create and start threads for each tile
    threads = []
    for i in range(n_tiles):
        for j in range(n_tiles):
            t = threading.Thread(target=process_and_save_tile, args=(i, j))
            threads.append(t)
            t.start()
    
    # Wait for all threads to complete
    for t in threads:
        t.join()
    
    if not tile_results:
        raise RuntimeError("No tiles were successfully processed")
    
    # Merge the tiff files
    print("Merging tile files...")
    merged_tiff = os.path.join(save_directory, 'PredictedChlorophyll_Merged.tif')
    tile_files = merge_tiff_files(save_directory, 'PredictedChlorophyll_Tile', merged_tiff)
    
    # Clean up individual tile files
    print("Cleaning up individual tile files...")
    cleanup_tiles(tile_files)
    
    # Merge all tiles in Earth Engine for visualization
    merged_result = ee.ImageCollection(tile_results).mosaic()
    return merged_result

def add_legend(map_obj, title, palette, min_value, max_value):
    """Add a legend to the map"""
    legend_html = f"""
    <div style='padding: 10px; background-color: white; border-radius: 5px;'>
        <h4>{title}</h4>
        <div style='display: flex; align-items: center;'>
            <span>{min_value:.2f}</span>
            <div style='flex-grow: 1; height: 20px; background: linear-gradient(to right, {", ".join(palette)}); margin: 0 10px;'></div>
            <span>{max_value:.2f}</span>
        </div>
    </div>
    """
    map_obj.add_html(legend_html)

def main():
    # Main execution parameters
    date_range = ['2020-01-01', '2020-04-01']
    save_directory = 'analises_clorofila/cacu'
    n_tiles = 4  # NxN grid
    
    try:
        # Process the entire AOI in tiles
        print("Starting tile processing...")
        final_result = process_aoi_in_tiles(aoi, n_tiles, date_range, model, scaler, save_directory)
        
        # Calculate min and max values for chlorophyll prediction
        min_max_values = final_result.select('chlorophyll_pred').reduceRegion(
            reducer=ee.Reducer.minMax(),
            geometry=aoi,
            scale=30,
            maxPixels=1e9
        ).getInfo()
        
        min_value = min_max_values['chlorophyll_pred_min']
        max_value = min_max_values['chlorophyll_pred_max']
        
        # Display results
        Map = geemap.Map()
        Map.centerObject(aoi, zoom=10)
        Map.add_basemap('SATELLITE')
        
        vis_params = {
            'min': min_value,
            'max': max_value,
            'bands': ['chlorophyll_pred'],
            'palette': [
                'blue', 'cyan', 'green', 'yellow', 'orange', 'red',
                'darkred', 'purple', 'magenta', 'brown', 'black'
            ]
        }
        
        Map.addLayer(final_result, vis_params, 'Predicted Chlorophyll')
        Map.addLayer(aoi, {'color': 'white', 'width': 2, 'fillColor': 'transparent'}, 'AOI Boundary')
        Map.addLayerControl()
        
        add_legend(Map, 'Predicted Chlorophyll', vis_params['palette'], min_value, max_value)
        
        print(f"\nProcessing complete. Merged file saved to: {os.path.join(save_directory, 'PredictedChlorophyll_Merged.tif')}")
        print("\nBands in the output TIFF file:")
        print("1-6: B2, B3, B4, B5, B8, B11 (Original Sentinel-2 bands)")
        print("7-9: NDCI, NDVI, FAI (Spectral indices)")
        print("10: Predicted Chlorophyll")
        
        return Map
        
    except Exception as e:
        print(f"Error in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    Map = main()    
    display(Map)
# Out:
# Model feature importances:
# B2: 0.10591678163828931
# B3: 0.09548249526637576
# B4: 0.062314885471840865
# B5: 0.03435734035674416
# B8: 0.056634818307155305
# B11: 0.05590603958608504
# NDCI: 0.05445562323735264
# NDVI: 0.07533380510799796
# FAI: 0.05697124706400951
# B3_B2_ratio: 0.12960579772752542
# B4_B3_ratio: 0.09017043564534706
# B5_B4_ratio: 0.08494749805158586
# Month: 0.06579228484423694
# Season: 0.017168937728718255
# Starting tile processing...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/b6574a38b6a7b1ea785724e8065ae945-2486dce244c548f17aa9225f33a4a2fc:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_1_1.tif
# Tile 1_1 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_1_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/eda22fd758ee7a5689ccb03cb8618b04-9b7c3981ef26c5b03c0680034d55ed42:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_1_2.tif
# Tile 1_2 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_1_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/93949d569300da37c5174d579c916a55-770d378244a431c19d0de18c02a92bc9:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_1_3.tif
# Tile 1_3 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_1_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/a27dca87b6502331aaf71bf34d2fa78f-e7c1b30b836e2a1c4c9503ef0416b632:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_1_4.tif
# Tile 1_4 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_1_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/475d994b7d701a98a4b463a8da2719a4-637033010066dbd3d2a711b4361450da:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_2_1.tif
# Tile 2_1 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_2_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/2320f7e01735af8d73cf0c5418b708a1-bdd3577d4661f19df4e6f4e391e873a5:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_2_2.tif
# Tile 2_2 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_2_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/dce15cef9b8c5e9e5db111916c05f552-dcfa075d539c5eba07f602e944e4346c:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_2_3.tif
# Tile 2_3 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_2_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/f67759cf07acd68ff13400492e1886d1-cdba71d85accf0af2269a3d2fe521b70:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_2_4.tif
# Tile 2_4 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_2_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/7b73f1527b066cb7d34bae6490adfa58-bee2c3ad35dc3e67e87fb456eb14b8ed:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_3_1.tif
# Tile 3_1 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_3_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/31bd705a52eefe198d03fe21b17a0b8a-01669a618ef0209eb3cbfe81d2a0f14b:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_3_2.tif
# Tile 3_2 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_3_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/6cd46699f47b817402734d14119be984-d44dfa93990248032254bea2fdf2f08c:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_3_3.tif
# Tile 3_3 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_3_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/af3e68625337fe307ec51be2aaec4a23-42d4de2c3a8ca968bf2d060a061ae538:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_4_1.tif
# Tile 4_1 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_4_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/85f4ac763fb3972b14f6b594c3e2a2de-965fcdfd6354f5646f9fb54960cd6ce9:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_3_4.tif
# Tile 3_4 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_3_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/5f72126e63119287cfda22bf4ed4b626-1498c4b51b1ce4a4287a1a4e44cd5081:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_4_2.tif
# Tile 4_2 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_4_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/59693b11835b47783f290d557c6e1a11-a7206cf7015822a728bf94ac97bb18a7:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_4_3.tif
# Tile 4_3 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_4_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-waterandrei/thumbnails/2c7b4200f784f1260e7e31feac3e407e-8d02f49fb2464b3e07f6a992925c33b1:getPixels
# Please wait ...
# Data downloaded to e:\Projetos\water_quality_maps\analises_clorofila\cacu\PredictedChlorophyll_Tile_4_4.tif
# Tile 4_4 processed and saved: analises_clorofila/cacu\PredictedChlorophyll_Tile_4_4.tif
# Merging tile files...
# Cleaning up individual tile files...
# Error in main execution: name 'cleanup_tiles' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 287
#     284         raise
#     286 if __name__ == "__main__":
# --> 287     Map = main()
#     288     display(Map)
#
# Cell In[1], line 240, in main()
#     237 try:
#     238     # Process the entire AOI in tiles
#     239     print("Starting tile processing...")
# --> 240     final_result = process_aoi_in_tiles(aoi, n_tiles, date_range, model, scaler, save_directory)
#     242     # Calculate min and max values for chlorophyll prediction
#     243     min_max_values = final_result.select('chlorophyll_pred').reduceRegion(
#     244         reducer=ee.Reducer.minMax(),
#     245         geometry=aoi,
#     246         scale=30,
#     247         maxPixels=1e9
#     248     ).getInfo()
#
# Cell In[1], line 211, in process_aoi_in_tiles(aoi, n_tiles, date_range, model, scaler, save_directory)
#     209 # Clean up individual tile files
#     210 print("Cleaning up individual tile files...")
# --> 211 cleanup_tiles(tile_files)
#     213 # Merge all tiles in Earth Engine for visualization
#     214 merged_result = ee.ImageCollection(tile_results).mosaic()
#
# NameError: name 'cleanup_tiles' is not defined
