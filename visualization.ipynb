# %%
import ee
import geemap
import os
from IPython.display import display

# Initialize Earth Engine
try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ee.Initialize()

# Define area of interest
aoi = ee.Geometry.Polygon([[[-45.559114, -18.954365], [-45.559114, -18.212409], 
                           [-44.839706, -18.212409], [-44.839706, -18.954365], 
                           [-45.559114, -18.954365]]])

# Read min and max values from stats file
stats_file_path = 'chlorophyll_analysis/Tres_Marias_20200101_stats.txt'
with open(stats_file_path, 'r') as f:
    lines = f.readlines()
    min_value = float(lines[2].split(': ')[1])
    max_value = float(lines[3].split(': ')[1])

print(f"Chlorophyll concentration range:")
print(f"Minimum: {min_value:.2f}")
print(f"Maximum: {max_value:.2f}")

# Get the water mask from Sentinel-2 data
sentinel2 = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
    .filterBounds(aoi) \
    .filterDate('2020-01-01', '2020-04-01') \
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20)) \
    .median()

# Calculate MNDWI for water masking
MNDWI = sentinel2.normalizedDifference(['B3', 'B11'])
water_mask = MNDWI.gt(0.3)

# Create and setup the map
Map = geemap.Map()
Map.centerObject(aoi, zoom=10)
Map.add_basemap('SATELLITE')

# Add the GeoTIFF directly to the map
geotiff_path = 'chlorophyll_analysis/Tres_Marias_20200101_chlorophyll.tif'

# Add raster layer
Map.add_raster(
    geotiff_path,
    palette=[
        '#0000ff', '#00ffff', '#00ff00', '#ffff00', '#ff7f00', '#ff0000',
        '#8b0000', '#800080', '#ff00ff', '#8b4513', '#000000'
    ],
    vmin=min_value,
    vmax=max_value,
    nodata=-9999,
    layer_name='Predicted Chlorophyll'
)

# Add water mask with corrected visualization
Map.addLayer(
    water_mask, 
    {'min': 0, 'max': 1, 'palette': ['black', 'blue']}, 
    'Water Mask',
    False  # Hidden by default
)

Map.addLayer(
    aoi, 
    {'color': 'white', 'width': 2, 'fillColor': '00000000'}, 
    'AOI Boundary'
)

Map.addLayerControl()

# Function to add legend
def add_legend(map_obj, title, palette, min_value, max_value):
    legend_html = f"""
    <div style='padding: 10px; background-color: white; border-radius: 5px;'>
        <h4>{title}</h4>
        <div style='display: flex; align-items: center;'>
            <span>{min_value:.2f}</span>
            <div style='flex-grow: 1; height: 20px; background: linear-gradient(to right, {", ".join(palette)}); margin: 0 10px;'></div>
            <span>{max_value:.2f}</span>
        </div>
    </div>
    """
    map_obj.add_html(legend_html)

# Add legend
add_legend(
    Map, 
    'Predicted Chlorophyll',
    [
        '#0000ff', '#00ffff', '#00ff00', '#ffff00', '#ff7f00', '#ff0000',
        '#8b0000', '#800080', '#ff00ff', '#8b4513', '#000000'
    ],
    min_value,
    max_value
)

# Display the map
display(Map)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Chlorophyll concentration range:
# Minimum: -0.34
# Maximum: 6.53
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File e:\Projetos\water_quality_maps\tempEnv\Lib\site-packages\ee\data.py:406, in _execute_cloud_call(call, num_retries)
#     405 try:
# --> 406   return call.execute(num_retries=num_retries)
#     407 except googleapiclient.errors.HttpError as e:
#
# File e:\Projetos\water_quality_maps\tempEnv\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File e:\Projetos\water_quality_maps\tempEnv\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/ee-waterandrei/maps?fields=name&alt=json returned "Image.visualize: Scale must be greater than zero and less than or equal to one, but was 0.0.". Details: "Image.visualize: Scale must be greater than zero and less than or equal to one, but was 0.0.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[17], line 70
#      60 Map.add_raster(
#      61     geotiff_path,
#      62     palette=vis_params['palette'],
#    (...)
#      66     layer_name='Predicted Chlorophyll'
#      67 )
#      69 # Add water mask layer
# ---> 70 Map.addLayer(
#      71     water_mask,
#      72     {'palette': ['000000', '0000ff'], 'opacity': 0},
#      73     'Water Mask'
#      74 )
#      76 Map.addLayer(
#      77     aoi,
#      78     {'color': 'white', 'width': 2, 'fillColor': '00000000'},
#      79     'AOI Boundary'
#      80 )
#      82 Map.addLayerControl()
#
# File e:\Projetos\water_quality_maps\tempEnv\Lib\site-packages\geemap\geemap.py:334, in Map.add_ee_layer(self, ee_object, vis_params, name, shown, opacity)
#     329         if has_plot_dropdown:
#     330             self._plot_dropdown_widget.options = list(
#     331                 self.ee_raster_layers.keys()
#     332             )
# --> 334 super().add_layer(ee_object, vis_params, name, shown, opacity)
#     336 if isinstance(ee_object, (ee.Image, ee.ImageCollection)):
#     337     if has_plot_dropdown:
#
# File e:\Projetos\water_quality_maps\tempEnv\Lib\site-packages\geemap\core.py:796, in Map.add_layer(self, ee_object, vis_params, name, shown, opacity)
#     794 if isinstance(ee_object, ee.ImageCollection):
#     795     ee_object = ee_object.mosaic()
# --> 796 tile_layer = ee_tile_layers.EELeafletTileLayer(
#     797     ee_object, vis_params, name, shown, opacity
#     798 )
#     800 # Remove the layer if it already exists.
#     801 self.remove(name)
#
# File e:\Projetos\water_quality_maps\tempEnv\Lib\site-packages\geemap\ee_tile_layers.py:144, in EELeafletTileLayer.__init__(self, ee_object, vis_params, name, shown, opacity, **kwargs)
#     134 """Initialize the ipyleaflet tile layer.
#     135
#     136 Args:
#    (...)
#     141     opacity (float, optional): The layer's opacity represented as a number between 0 and 1. Defaults to 1.
#     142 """
#     143 self._ee_object = ee_object
# --> 144 self.url_format = _get_tile_url_format(
#     145     ee_object, _validate_vis_params(vis_params)
#     146 )
#     147 super().__init__(
#     148     url=self.url_format,
#     149     attribution="Google Earth Engine",
#    (...)
#     154     **kwargs,
#     155 )
#
# File e:\Projetos\water_quality_maps\tempEnv\Lib\site-packages\geemap\ee_tile_layers.py:19, in _get_tile_url_format(ee_object, vis_params)
#      17 def _get_tile_url_format(ee_object, vis_params):
#      18     image = _ee_object_to_image(ee_object, vis_params)
# ---> 19     map_id_dict = ee.Image(image).getMapId(vis_params)
#      20     return map_id_dict["tile_fetcher"].url_format
#
# File e:\Projetos\water_quality_maps\tempEnv\Lib\site-packages\ee\image.py:156, in Image.getMapId(self, vis_params)
#     154 vis_image, request = self._apply_visualization(vis_params)
#     155 request['image'] = vis_image
# --> 156 response = data.getMapId(request)
#     157 response['image'] = self
#     158 return response
#
# File e:\Projetos\water_quality_maps\tempEnv\Lib\site-packages\ee\data.py:748, in getMapId(params)
#     743 queryParams = {
#     744     'fields': 'name',
#     745     'body': request,
#     746 }
#     747 _maybe_populate_workload_tag(queryParams)
# --> 748 result = _execute_cloud_call(
#     749     _get_cloud_projects()
#     750     .maps()
#     751     .create(parent=_get_projects_path(), **queryParams)
#     752 )
#     753 map_name = result['name']
#     754 url_format = '%s/%s/%s/tiles/{z}/{x}/{y}' % (
#     755     _tile_base_url, _cloud_api_utils.VERSION, map_name)
#
# File e:\Projetos\water_quality_maps\tempEnv\Lib\site-packages\ee\data.py:408, in _execute_cloud_call(call, num_retries)
#     406   return call.execute(num_retries=num_retries)
#     407 except googleapiclient.errors.HttpError as e:
# --> 408   raise _translate_cloud_exception(e)
#
# EEException: Image.visualize: Scale must be greater than zero and less than or equal to one, but was 0.0.
